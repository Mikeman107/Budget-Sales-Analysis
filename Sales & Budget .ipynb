# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_Calender = pd.read_excel("C:/Users/Lenovo/OneDrive/Desktop/py/Budget & Sales Analysis/archive/AdventureWorks_Database1.xlsx", sheet_name='Calender')

# %%
df_Calender
# Out:
#            Date   DateKey  Year Quarter  MonthNum Month FiscalYear  \
# 0    2016-04-03  20160403  2016      Q2         4   Apr     FY2016
# 1    2016-04-04  20160404  2016      Q2         4   Apr     FY2016
# 2    2016-04-05  20160405  2016      Q2         4   Apr     FY2016
# 3    2016-04-06  20160406  2016      Q2         4   Apr     FY2016
# 4    2016-04-07  20160407  2016      Q2         4   Apr     FY2016
# ...         ...       ...   ...     ...       ...   ...        ...
# 1456 2014-06-18  20140618  2014      Q2         6   Jun     FY2014
# 1457 2014-06-19  20140619  2014      Q2         6   Jun     FY2014
# 1458 2014-06-20  20140620  2014      Q2         6   Jun     FY2014
# 1459 2014-06-21  20140621  2014      Q2         6   Jun     FY2014
# 1460 2014-06-22  20140622  2014      Q2         6   Jun     FY2014
#
#      FiscalQuarter  FiscalMonthNum FiscalMonth MonthYear MonthYearLong  \
# 0              FQ4              10         Apr    Apr-16      Apr-2016
# ...

# %%
df_Calender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            1461 non-null   object
#  1   DateKey         1461 non-null   int64
#  2   Year            1461 non-null   int64
#  3   Quarter         1461 non-null   object
#  4   Month           1461 non-null   object
#  5   FiscalYear      1461 non-null   object
#  6   FiscalQuarter   1461 non-null   object
#  7   FiscalMonthNum  1461 non-null   int64
#  8   FiscalMonth     1461 non-null   object
#  9   MonthYear       1461 non-null   object
#  10  Weekday         1461 non-null   object
# dtypes: int64(3), object(8)
# memory usage: 125.7+ KB

# %%
df_Calender.columns
# Out:
# Index(['Date', 'DateKey', 'Year', 'Quarter', 'Month', 'FiscalYear',
#        'FiscalQuarter', 'FiscalMonthNum', 'FiscalMonth', 'MonthYear',
#        'Weekday'],
#       dtype='object')

# %%
df_Calender = df_Calender.drop(columns=['MonthNum', 'MonthYearLong','MonthYearNum','WeekdayNum','WeekdayWeekend'])

# %%
df_Calender['Date'] = df_Calender['Date'].dt.date

# %%
df_Calender['Date']
# Out:
# 0       2016-04-03
# 1       2016-04-04
# 2       2016-04-05
# 3       2016-04-06
# 4       2016-04-07
#            ...
# 1456    2014-06-18
# 1457    2014-06-19
# 1458    2014-06-20
# 1459    2014-06-21
# 1460    2014-06-22
# Name: Date, Length: 1461, dtype: object

# %%
df_Calender.head(5)
# Out:
#          Date   DateKey  Year Quarter Month FiscalYear FiscalQuarter  \
# 0  2016-04-03  20160403  2016      Q2   Apr     FY2016           FQ4
# 1  2016-04-04  20160404  2016      Q2   Apr     FY2016           FQ4
# 2  2016-04-05  20160405  2016      Q2   Apr     FY2016           FQ4
# 3  2016-04-06  20160406  2016      Q2   Apr     FY2016           FQ4
# 4  2016-04-07  20160407  2016      Q2   Apr     FY2016           FQ4
#
#    FiscalMonthNum FiscalMonth MonthYear Weekday
# 0              10         Apr    Apr-16     Sun
# 1              10         Apr    Apr-16     Mon
# 2              10         Apr    Apr-16     Tue
# 3              10         Apr    Apr-16     Wed
# 4              10         Apr    Apr-16     Thu

# %%
df_Calender.to_excel("C:/Users/Lenovo/OneDrive/Desktop/py/Budget & Sales Analysis/Final Data/Calender.xlsx", index=False)

# %%
df_Customers = pd.read_excel("C:/Users/Lenovo/OneDrive/Desktop/py/Budget & Sales Analysis/archive/AdventureWorks_Database1.xlsx", sheet_name='Customers')

# %%
df_Customers
# Out:
#        CustomerKey  FirstName LastName            FullName  BirthDate  \
# 0            11000        Jon     Yang           Yang, Jon 1966-04-08
# 1            11001     Eugene    Huang       Huang, Eugene 1965-05-14
# 2            11002      Ruben   Torres       Torres, Ruben 1965-08-12
# 3            11003    Christy      Zhu        Zhu, Christy 1968-02-15
# 4            11004  Elizabeth  Johnson  Johnson, Elizabeth 1968-08-08
# ...            ...        ...      ...                 ...        ...
# 18479        29479      Tommy     Tang         Tang, Tommy 1958-07-04
# 18480        29480       Nina     Raji          Raji, Nina 1960-11-10
# 18481        29481       Ivan     Suri          Suri, Ivan 1960-01-05
# 18482        29482    Clayton    Zhang      Zhang, Clayton 1959-03-05
# 18483        29483      Jésus  Navarro      Navarro, Jésus 1959-12-08
#
#       MaritalStatus Gender  YearlyIncome  TotalChildren  NumberChildrenAtHome  \
# ...

# %%
df_Customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18484 entries, 0 to 18483
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerKey      18484 non-null  int64
#  1   FirstName        18484 non-null  object
#  2   LastName         18484 non-null  object
#  3   BirthDate        18484 non-null  object
#  4   MaritalStatus    18484 non-null  object
#  5   Gender           18484 non-null  object
#  6   YearlyIncome     18484 non-null  int64
#  7   TotalChildren    18484 non-null  int64
#  8   Education        18484 non-null  object
#  9   Occupation       18484 non-null  object
#  10  HouseOwnerFlag   18484 non-null  int64
#  11  NumberCarsOwned  18484 non-null  int64
# dtypes: int64(5), object(7)
# memory usage: 1.7+ MB

# %%
df_Customers.columns
# Out:
# Index(['CustomerKey', 'FirstName', 'LastName', 'FullName', 'BirthDate',
#        'MaritalStatus', 'Gender', 'YearlyIncome', 'TotalChildren',
#        'NumberChildrenAtHome', 'Education', 'Occupation', 'HouseOwnerFlag',
#        'NumberCarsOwned', 'AddressLine1', 'DateFirstPurchase',
#        'CommuteDistance'],
#       dtype='object')

# %%
df_Customers = df_Customers.drop(columns = ['NumberChildrenAtHome','AddressLine1','FullName','CommuteDistance','DateFirstPurchase'])

# %%
df_Customers.head(5)
# Out:
#    CustomerKey  FirstName LastName  BirthDate MaritalStatus Gender  \
# 0        11000        Jon     Yang 1966-04-08             M      M
# 1        11001     Eugene    Huang 1965-05-14             S      M
# 2        11002      Ruben   Torres 1965-08-12             M      M
# 3        11003    Christy      Zhu 1968-02-15             S      F
# 4        11004  Elizabeth  Johnson 1968-08-08             S      F
#
#    YearlyIncome  TotalChildren  Education    Occupation  HouseOwnerFlag  \
# 0         90000              2  Bachelors  Professional               1
# 1         60000              3  Bachelors  Professional               0
# 2         60000              3  Bachelors  Professional               1
# 3         70000              0  Bachelors  Professional               0
# 4         80000              5  Bachelors  Professional               1
#
#    NumberCarsOwned
# 0                0
# 1                1
# 2                1
# 3                1
# 4                4

# %%
df_Customers['BirthDate'] = df_Customers['BirthDate'].dt.date

# %%
df_Customers.to_excel("C:/Users/Lenovo/OneDrive/Desktop/py/Budget & Sales Analysis/Final Data/Customers.xlsx", index=False)

# %%
df_Products = pd.read_excel("C:/Users/Lenovo/OneDrive/Desktop/py/Budget & Sales Analysis/archive/AdventureWorks_Database1.xlsx", sheet_name='Products')

# %%
df_Products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606 entries, 0 to 605
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ProductKey    606 non-null    int64
#  1   ProductName   606 non-null    object
#  2   SubCategory   606 non-null    object
#  3   Category      606 non-null    object
#  4   StandardCost  606 non-null    float64
#  5   Color         606 non-null    object
#  6   ListPrice     606 non-null    float64
#  7   ProductLine   606 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 38.0+ KB

# %%
df_Sales.isnull().sum()
# Out:
# ProductKey           0
# OrderDate            0
# CustomerKey          0
# SalesTerritoryKey    0
# OrderQuantity        0
# UnitPrice            0
# TotalProductCost     0
# SalesAmount          0
# TaxAmt               0
# dtype: int64

# %%
df_Products.columns
# Out:
# Index(['ProductKey', 'ProductName', 'SubCategory', 'Category', 'StandardCost',
#        'Color', 'ListPrice', 'DaysToManufacture', 'ProductLine', 'ModelName',
#        'Photo', 'ProductDescription', 'StartDate'],
#       dtype='object')

# %%
df_Products = df_Products.drop(columns = ['ModelName'])

# %%
df_Territory.columns
# Out:
# Index(['Category', 'Subcategory', 'ProductName', 'ProductKey', 'Jan, 2016',
#        'Feb, 2016', 'Mar, 2016', 'Apr, 2016', 'May, 2016', 'Jun, 2016',
#        'Jul, 2016', 'Aug, 2016', 'Sep, 2016', 'Oct, 2016', 'Nov, 2016',
#        'Dec, 2016'],
#       dtype='object')

# %%
df_Products.to_excel("C:/Users/Lenovo/OneDrive/Desktop/py/Budget & Sales Analysis/Final Data/Products.xlsx", index=False)

# %%
df_Sales = pd.read_excel("C:/Users/Lenovo/OneDrive/Desktop/py/Budget & Sales Analysis/archive/AdventureWorks_Database1.xlsx", sheet_name='Sales')

# %%
df_Sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58189 entries, 0 to 58188
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ProductKey         58189 non-null  int64
#  1   OrderDate          58189 non-null  object
#  2   CustomerKey        58189 non-null  int64
#  3   SalesTerritoryKey  58189 non-null  int64
#  4   OrderQuantity      58189 non-null  int64
#  5   UnitPrice          58189 non-null  float64
#  6   TotalProductCost   58189 non-null  float64
#  7   SalesAmount        58189 non-null  float64
#  8   TaxAmt             58189 non-null  float64
# dtypes: float64(4), int64(4), object(1)
# memory usage: 4.0+ MB

# %%
df_Sales.columns
# Out:
# Index(['ProductKey', 'OrderDate', 'ShipDate', 'CustomerKey', 'PromotionKey',
#        'SalesTerritoryKey', 'SalesOrderNumber', 'SalesOrderLineNumber',
#        'OrderQuantity', 'UnitPrice', 'TotalProductCost', 'SalesAmount',
#        'TaxAmt'],
#       dtype='object')

# %%
df_Sales = df_Sales.drop(columns = ['ShipDate', 'PromotionKey', 'SalesOrderNumber', 'SalesOrderLineNumber' ])

# %%
df_Sales['OrderDate'] = df_Sales['OrderDate'].dt.date

# %%
df_Sales.to_excel("C:/Users/Lenovo/OneDrive/Desktop/py/Budget & Sales Analysis/Final Data/Sales.xlsx", index=False)

# %%
df_Territory = pd.read_excel("C:/Users/Lenovo/OneDrive/Desktop/py/Budget & Sales Analysis/archive/AdventureWorks_Database1.xlsx", sheet_name='Territory')

# %%
df_Territory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SalesTerritoryKey  11 non-null     int64
#  1   Region             10 non-null     object
#  2   Country            10 non-null     object
#  3   Group              10 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 480.0+ bytes

# %%
df_Territory.columns
# Out:
# Index(['SalesTerritoryKey', 'Region', 'Country', 'Group', 'RegionImage'], dtype='object')

# %%
df_Territory = df_Territory.drop('RegionImage' , axis = 1)

# %%
df_Territory.to_excel("C:/Users/Lenovo/OneDrive/Desktop/py/Budget & Sales Analysis/Final Data/Territory.xlsx", index=False)

# %%
df_budget = pd.read_excel("C:/Users/Lenovo/OneDrive/Desktop/py/Budget & Sales Analysis/archive/Budget1.xlsx",)

# %%
df_budget
# Out:
#        Category        Subcategory                 ProductName  ProductKey  \
# 0   Accessories         Bike Racks         Hitch Rack - 4-Bike         483
# 1   Accessories        Bike Stands      All-Purpose Bike Stand         486
# 2   Accessories  Bottles and Cages       Water Bottle - 30 oz.         477
# 3   Accessories           Cleaners       Bike Wash - Dissolver         484
# 4   Accessories            Fenders       Fender Set - Mountain         485
# 5   Accessories            Helmets       Sport-100 Helmet, Red         212
# 6   Accessories    Hydration Packs     Hydration Pack - 70 oz.         487
# 7   Accessories    Tires and Tubes         Patch Kit/8 Patches         480
# 8         Bikes     Mountain Bikes     Mountain-100 Silver, 38         344
# 9         Bikes         Road Bikes            Road-150 Red, 62         310
# 10        Bikes      Touring Bikes       Touring-2000 Blue, 60         560
# ...

# %%
df_budget.to_excel("C:/Users/Lenovo/OneDrive/Desktop/py/Budget & Sales Analysis/Final Data/Budget.xlsx", index=False)

# %%
n = eval(input("Enter Number of students: "))


dict1 = {}
for i in n:
    std_name = eval(input("Enter student name: "))
    std_% = eval(input("Enter % of marks of Student: "))
    di

# %%
dict12 = {}
type(dict12)
